# %% [markdown]
# ## 1.1 Contents<a id='1.1_Contents'></a>
# * [1 Data wrangling](#1_Data_wrangling)
#   * [1.1 Contents](#1.1_Contents)
#   * [1.2 Introduction](#1.2_Introduction)
#   * [1.3 Imports](#1.3_Imports)
#   * [1.4 Objectives](#1.4_Objectives)
#   * [1.5 Load The Historical CPI Data](#1.5_Load_The_Historical_CPI_Data)
#   * [1.6 Explore The Data](#1.6_Explore_The_Data)
#     * [1.6.1 Find Your Resort Of Interest](#1.6.1_Find_Your_Resort_Of_Interest)
#     * [1.6.2 Number Of Missing Values By Column](#1.6.2_Number_Of_Missing_Values_By_Column)
#     * [1.6.3 Categorical Features](#1.6.3_Categorical_Features)
#       * [1.6.3.1 Unique Resort Names](#1.6.3.1_Unique_Resort_Names)
#       * [1.6.3.2 Region And State](#1.6.3.2_Region_And_State)
#       * [1.6.3.3 Number of distinct regions and states](#1.6.3.3_Number_of_distinct_regions_and_states)
#       * [1.6.3.4 Distribution Of Resorts By Region And State](#1.6.3.4_Distribution_Of_Resorts_By_Region_And_State)
#       * [1.6.3.5 Distribution Of Ticket Price By State](#1.6.3.5_Distribution_Of_Ticket_Price_By_State)
#         * [1.6.3.5.1 Average weekend and weekday price by state](#1.6.3.5.1_Average_weekend_and_weekday_price_by_state)
#         * [1.6.3.5.2 Distribution of weekday and weekend price by state](#1.6.3.5.2_Distribution_of_weekday_and_weekend_price_by_state)
#     * [1.6.4 Numeric Features](#1.6.4_Numeric_Features)
#       * [1.6.4.1 Numeric data summary](#1.6.4.1_Numeric_data_summary)
#       * [1.6.4.2 Distributions Of Feature Values](#1.6.4.2_Distributions_Of_Feature_Values)
#         * [1.6.4.2.1 SkiableTerrain_ac](#1.6.4.2.1_SkiableTerrain_ac)
#         * [1.6.4.2.2 Snow Making_ac](#1.6.4.2.2_Snow_Making_ac)
#         * [1.6.4.2.3 fastEight](#1.6.4.2.3_fastEight)
#         * [1.6.4.2.4 fastSixes and Trams](#1.6.4.2.4_fastSixes_and_Trams)
#   * [1.7 Derive State-wide Summary Statistics For Our Market Segment](#1.7_Derive_State-wide_Summary_Statistics_For_Our_Market_Segment)
#   * [1.8 Drop Rows With No Price Data](#1.8_Drop_Rows_With_No_Price_Data)
#   * [1.9 Review distributions](#1.9_Review_distributions)
#   * [1.10 Population data](#1.10_Population_data)
#   * [1.11 Target Feature](#1.11_Target_Feature)
#     * [1.11.1 Number Of Missing Values By Row - Resort](#1.11.1_Number_Of_Missing_Values_By_Row_-_Resort)
#   * [1.12 Save data](#1.12_Save_data)
#   * [1.13 Summary](#1.13_Summary)

# %% [markdown]
# ## 1.2 Introduction<a id='2.2_Introduction'></a>

# %% [markdown]
# This step focuses on collecting data, organizing it, and making sure it's well defined. Specifically, we have two sets of data - the historical data and the recent data are spread into two sets.

# %% [markdown]
# ### 1.2.1 Recap Of Data Science Problem<a id='1.2.1_Recap_Of_Data_Science_Problem'></a>

# %% [markdown]
# The purpose of this data science project is to come up with a forecasting model for organizations such as the federal reserve or any private business that is interested in forecasting the inflation rate in the near future. The Federal Reserve’s dual mandate requires monetary policy to aim for both maximum employment and price stability. [As the RMSEs show](https://www.clevelandfed.org/en/newsroom-and-events/publications/economic-trends/2011-economic-trends/et-20110107-the-accuracy-of-cpi-inflation-forecasts.aspx), the accuracy of inflation forecasts has varied a lot over time. Inflation forecasts were not very accurate in the 1970s and 1980s. Accuracy improved in the 1990s and began to fall again in the 2000s.
#
# This model is aimed to utilize disaggregate information to improve the forecast accuracy for the aggregated inflation rate. The disaggregated information has been proposed by [many researchers](https://www.ecb.europa.eu/pub/pdf/scpwps/ecbwp589.pdf) with a dynamic factor model to reduce the dimensionality. However, the findings are mixed. This project aims to identify a statistical model that can improve the dynamic factor model in accuracy.
#
# The final product of the project is to generate a inflation forecasting for the next 12 months in a highly automated manner.

# %% [markdown]
# ## 1.3 Imports<a id='1.3_Imports'></a>

# %%
#Import pandas, matplotlib.pyplot, and seaborn in the correct lines below
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

from library.sb_utils import save_file

# %% [markdown]
# ## 1.4 Objectives<a id='1.4_Objectives'></a>

# %% [markdown]
# There are some fundamental goals of the data wrangling process:
#
# * Clean the data and create a data set for the model.
#
# * Create a pipeline function that combines recently released CPI data with the historical data.
#
# * Identify the fundamental issues with the data.

# %% [markdown]
# ## 1.5 Load The Historical CPI Data<a id='1.5_Load_The_Historical_CPI_Data'></a>

# %% [markdown]
# There are 15 disaggregated features to be imported from the raw data. First of all, we import all the data frames and clean them one by one. To achieve this, I create a function that does data importation and cleaning automatically.

# %%
# the supplied CSV data file is the raw_data directory
import calendar
from datetime import datetime
from functools import reduce
import matplotlib.pyplot as plt

names = []
for root, dirs, files in os.walk("../data/raw_data"):
    for filename in files:
        names.append(filename)

        
def function(name):
    df = pd.read_excel('../data/raw_data/' + name)[10:]
    df.columns = list(df.iloc[0])
    df.drop(10, inplace = True)
    df.drop(['HALF1', 'HALF2'], axis = 1, inplace = True)
    df.set_index('Year', inplace = True)
    raw_cpi = [list(df.iloc[i]) for i in range(0,df.shape[0])]
    cpi = np.reshape(raw_cpi, (12 * df.shape[0]))
    date = [datetime(year=y, month=m, day=calendar.monthrange(y,m)[1]) for y in range(df.index[0],df.index[-1] + 1) for m in range(1,13)]
    return pd.DataFrame({'date':date, name[0:-5]:cpi}) 


dfs = [function(name) for name in names]
df_final = reduce(lambda left,right: pd.merge(left,right,on='date',how = 'left'), dfs)
df_final.set_index('date', inplace = True)
df_final.dropna(inplace = True)

# %%
#Call the head method on df_final to see a summary of the data
df_final.head()
# Out:
#             Medical care services  Transportation services  Electricity  \
# date
# 1957-03-31                   16.8                     23.7         28.7
# 1957-06-30                   17.0                     24.0         28.7
# 1957-09-30                   17.1                     24.4         28.7
# 1957-12-31                   17.4                     24.6         28.8
# 1958-03-31                   17.6                     25.5         28.9
#
#             Food at home  Alcoholic beverages  Utility (piped) gas service  \
# date
# 1957-03-31          30.2                 42.1                         15.0
# 1957-06-30          30.6                 42.0                         14.9
# 1957-09-30          30.9                 42.1                         15.3
# 1957-12-31          30.9                 42.1                         15.4
# 1958-03-31          32.4                 42.1                         15.8
#
#             Commodities less food and energy commodities  Food away from home  \
# date
# 1957-03-31                                          37.1                 23.2
# 1957-06-30                                          37.3                 23.4
# 1957-09-30                                          37.5                 23.7
# 1957-12-31                                          37.8                 23.8
# 1958-03-31                                          37.7                 23.9
#
#             Shelter  Motor fuel  Services less energy services  \
# date
# 1957-03-31     23.7        24.0                           21.7
# 1957-06-30     23.9        23.9                           21.8
# 1957-09-30     24.2        23.7                           22.1
# 1957-12-31     24.3        23.7                           22.3
# 1958-03-31     24.4        23.4                           22.6
#
#             Fuel oil and other fuels  All items  Medical care commodities  \
# date
# 1957-03-31                      14.2       27.8                      44.0
# 1957-06-30                      13.8       28.1                      44.7
# 1957-09-30                      13.9       28.3                      44.8
# 1957-12-31                      14.1       28.4                      45.4
# 1958-03-31                      13.9       28.8                      45.9
#
#             Apparel
# date
# 1957-03-31     44.4
# 1957-06-30     44.4
# 1957-09-30     44.7
# 1957-12-31     44.8
# 1958-03-31     44.6

# %% [markdown]
# `Aggregation_Level` is the level of disaggregation for the CPI data. `Personal consumption expenditures` is the aggregated CPI index, including food and energy, which I will use to compute the inflation rate as the target feature.

# %% [markdown]
# ## 1.6 Exploring the Data<a id='1.6_Exploring_the_Data'></a>

# %% [markdown]
# ## 1.6.1 Check Unbalancedness<a id='1.6.1_Check Unbalancedness'></a>

# %% [markdown]
# The disaggregated data set has a tree structure. The variable `Terminal_Category` indicates whether the tree ends as a leaf in a specific sector. Here I show that the tree structure is unbalanced with terminal nodes showing up on multiple levels.

# %%
def count_level(historical_cpi, level):
    selected_columns = historical_cpi.columns[(historical_cpi.iloc[1] == level)]
    return len(selected_columns), sum(historical_cpi[selected_columns].iloc[2] == 1)

count_df = pd.DataFrame([count_level(historical_cpi, level) for level in range(0,10)], columns = ['#Categories', '#Terminal'])
count_df.index.name = 'Disaggregation Level'
count_df
# Out:
#                       #Categories  #Terminal
# Disaggregation Level
# 0                               1          0
# 1                               2          0
# 2                               4          1
# 3                              15          0
# 4                              54          9
# 5                             129         96
# 6                              94         84
# 7                              26         22
# 8                               9          9
# 9                               0          0

# %% [markdown]
# This analysis shows that the first terminal node shows up in disaggregation level 2. The data structure is not balanced in general, with terminal nodes showing up at multiple levels. The deepest disaggregation is level 8, which is the upper bound for the feature selection in terms of disaggregation. The following subsection highlights the feature selection strategy for the disaggregated data set.

# %% [markdown]
# ## 1.6.2 Level Selection Strategy<a id='1.6.2_Level Selection_Strategy'></a>

# %% [markdown]
# The following tree structure is a generic unbalanced tree. It only serves to demonstrate the level selection strategy.
#
# -If the disaggregation level is 0, we only use variable `7` as the feature.
#
# -If the disaggregation level is 1, we only use variable `3` and `11` as the features.
#
# -If the disaggregation level is 2, we only use variable `1`, `5`, `9`, `13` as the features.
#
# -If the disaggregation level is 3, we only use variable `1`, `4`, `6`, `9`, `12`, `14` as the features.
#
# <img src="../images/data_structure_demo.png" width="480">
#
#
# <br>Two things to note for this level selection strategy. If we choose the level to be 0, we discard all the disaggregated information and only use the aggregated information to predict. We don't repeat the more aggregated information if all the disaggregated information is selected. For example, at level 1, we only choose `3` and `11` and *not* `7` to avoid redundancy. If the level contains missing nodes, we go up to find the nearest parent as a substitute. That's why node `1` and `9` are included when we choose level 3.

# %% [markdown]
# ## 1.6.3 Selecting Features with Level <a id='1.6.3_Selecting_Features_with_Level'></a>

# %% [markdown]
# Here I briefly describe the algorithm that I use to apply the level selecting strategy given level `l`:
#
# 1. Select all the features in the level `l`;
# 2. Go back to level `l-1` and add all the terminal features;
# 3. Repeat step 2 until the level hits 0, then stop;

# %%
# Create a function that selects the features according to a level
def extract_level(historical_cpi, level):
    selected_columns = list(historical_cpi.columns[(historical_cpi.iloc[1] == level)])
    while level > 0:
        level = level - 1
        selected_columns_add_candidates = list(historical_cpi.columns[(historical_cpi.iloc[1] == level)])
        bool_list = list(historical_cpi[selected_columns_add_candidates].iloc[2] == 1)
        add_index = [i for i, val in enumerate(bool_list) if val] 
        selected_columns += [selected_columns_add_candidates[i] for i in add_index]
    return selected_columns


select_df = pd.DataFrame([len(extract_level(historical_cpi, level)) for level in range(0,9)], columns = ['#Features'])
select_df.index.name = 'Disaggregation Level'
select_df
# Out:
#                       #Features
# Disaggregation Level
# 0                             1
# 1                             2
# 2                             4
# 3                            16
# 4                            55
# 5                           139
# 6                           200
# 7                           216
# 8                           221

# %% [markdown]
# The table above shows that when we choose a deeper level of disaggregation, more features get selected. One question that naturally arises is which level of disaggregation should we use. If the level is too small, then we are not fully utilizing the disaggregated data. If the level is too high, we might risk incorporating too much noise and overfitting the model.

# %%
extract_level(historical_cpi, 3)
# Out:
# ['Motor vehicles and parts',
#  'Furnishings and durable household equipment',
#  'Recreational goods and vehicles',
#  'Other durable goods',
#  'Food and beverages purchased for off-premises consumption',
#  'Clothing and footwear',
#  'Gasoline and other energy goods',
#  'Other nondurable goods',
#  'Housing and utilities',
#  'Health care',
#  'Transportation services',
#  'Recreation services',
#  'Food services and accommodations',
#  'Financial services and insurance',
#  'Other services',
#  'Final consumption expenditures of nonprofit institutions serving households (NPISHs) (132)']

# %% [markdown]
# ## 1.7 Import Recent CPI Data<a id='1.7_Import_Recent_CPI_Data'></a>

# %% [markdown]
# ## 1.7.1 Import Raw Data <a id='1.7.1_Convert_CPI_to_Inflation'></a>

# %%
historical_cpi
# Out:
#                   Date  Personal consumption expenditures    Goods  \
# 0      BEA_Line_Number                              1.000    2.000
# 1    Aggregation_Level                              0.000    1.000
# 2    Terminal_Category                              0.000    0.000
# 3               195901                             17.124   28.009
# 4               195902                             17.138   28.022
# ..                 ...                                ...      ...
# 706             201708                            112.629  101.162
# 707             201709                            113.077  101.876
# 708             201710                            113.243  101.679
# 709             201711                            113.515  101.943
# 710             201712                            113.640  101.778
#
#      Durable goods  Motor vehicles and parts  New motor vehicles (55)  \
# 0            3.000                     4.000                    5.000
# 1            2.000                     3.000                    4.000
# 2            0.000                     0.000                    0.000
# 3           54.478                    32.602                   38.531
# 4           54.510                    32.652                   38.530
# ..             ...                       ...                      ...
# 706         86.278                   107.990                  109.084
# 707         86.061                   107.895                  108.688
# 708         86.023                   107.869                  108.485
# 709         85.817                   108.125                  108.650
# 710         85.722                   108.924                  109.357
#
#      New autos  New domestic autos  New foreign autos   New light trucks  ...  \
# 0        6.000               7.000              8.000              9.000  ...
# 1        5.000               6.000              6.000              5.000  ...
# 2        0.000               1.000              1.000              1.000  ...
# 3       38.961              38.943             38.943             36.570  ...
# 4       38.961              38.943             38.943             36.570  ...
# ..         ...                 ...                ...                ...  ...
# 706    103.250             103.261            103.256            112.333  ...
# 707    102.767             102.781            102.777            111.966  ...
# 708    102.437             102.449            102.444            111.794  ...
# 709    102.812             102.822            102.817            111.883  ...
# 710    103.504             103.513            103.508            112.600  ...
#
#      Other household services  Foreign travel by U.S. residents (129)  \
# 0                     326.000                                 328.000
# 1                       5.000                                   4.000
# 2                       1.000                                   0.000
# 3                       9.999                                  17.004
# 4                      10.050                                  17.025
# ..                        ...                                     ...
# 706                   117.817                                 105.739
# 707                   117.814                                 108.169
# 708                   118.676                                 108.543
# 709                   118.980                                 108.245
# 710                   118.949                                 107.883
#
#      Passenger fares for foreign travel  \
# 0                               329.000
# 1                                 5.000
# 2                                 1.000
# 3                                17.641
# 4                                17.699
# ..                                  ...
# 706                             110.982
# 707                             118.160
# 708                             121.458
# 709                             120.609
# 710                             119.503
#
#      U.S. travel outside the United States  U.S. student expenditures  \
# 0                                  330.000                    331.000
# 1                                    5.000                      5.000
# 2                                    1.000                      1.000
# 3                                   16.811                        NaN
# 4                                   16.811                        NaN
# ..                                     ...                        ...
# 706                                101.645                    106.260
# 707                                102.328                    106.994
# 708                                101.668                    106.291
# 709                                101.544                    106.153
# 710                                101.438                    106.037
#
#      Less: Expenditures in the United States by nonresidents (130)  \
# 0                                              332.000
# 1                                                4.000
# 2                                                0.000
# 3                                               13.005
# 4                                               13.073
# ..                                                 ...
# 706                                            117.079
# 707                                            118.789
# 708                                            119.482
# 709                                            119.867
# 710                                            119.351
#
#      Foreign travel in the United States  Medical expenditures of foreigners  \
# 0                                333.000                             334.000
# 1                                  5.000                               5.000
# 2                                  1.000                               1.000
# 3                                 14.872                                 NaN
# 4                                 14.950                                 NaN
# ..                                   ...                                 ...
# 706                              113.229                             147.591
# 707                              115.167                             147.916
# 708                              115.887                             148.672
# 709                              116.249                             148.874
# 710                              115.549                             149.212
#
#      Expenditures of foreign students in the United States  \
# 0                                              335.000
# 1                                                5.000
# 2                                                1.000
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 706                                            135.277
# 707                                            136.095
# 708                                            136.570
# 709                                            137.016
# 710                                            137.227
#
#      Final consumption expenditures of nonprofit institutions serving households (NPISHs) (132)
# 0                                              336.000
# 1                                                2.000
# 2                                                1.000
# 3                                               54.163
# 4                                               53.932
# ..                                                 ...
# 706                                            117.950
# 707                                            118.903
# 708                                            117.452
# 709                                            118.350
# 710                                            118.954
#
# [711 rows x 335 columns]

# %%
file_name_2017 = "../raw_data/cpi-u-201712.xlsx"
df = pd.read_excel(file_name_2017)  
df
# Out:
#        Unnamed: 0  \
# 0             NaN
# 1             NaN
# 2    Indent Level
# 3             NaN
# 4             NaN
# ..            ...
# 419           NaN
# 420           NaN
# 421           NaN
# 422           NaN
# 423           NaN
#
#     Consumer Price Index for All Urban Consumers (CPI-U): U.S. city average, by expenditure category, December 2017  \
# 0                [1982-84=100, unless otherwise noted]
# 1                                                  NaN
# 2                                 Expenditure category
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 419          (15) Indexes on a December 2001=100 base.
# 420          (16) Indexes on a December 1982=100 base.
# 421          (17) Indexes on a December 1996=100 base.
# 422          (18) Indexes on a December 1988=100 base.
# 423  NOTE: Index applies to a month as a whole, not...
#
#                            Unnamed: 2          Unnamed: 3  Unnamed: 4  \
# 0                                 NaN                 NaN         NaN
# 1                                 NaN                 NaN         NaN
# 2    Relative\nimportance\nNov.\n2017  Unadjusted indexes         NaN
# 3                                 NaN          Dec.\n2016  Jan.\n2017
# 4                                 NaN                 NaN         NaN
# ..                                ...                 ...         ...
# 419                               NaN                 NaN         NaN
# 420                               NaN                 NaN         NaN
# 421                               NaN                 NaN         NaN
# 422                               NaN                 NaN         NaN
# 423                               NaN                 NaN         NaN
#
#      Unnamed: 5  Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  \
# 0           NaN         NaN         NaN        NaN         NaN  ...
# 1           NaN         NaN         NaN        NaN         NaN  ...
# 2           NaN         NaN         NaN        NaN         NaN  ...
# 3    Feb.\n2017  Mar.\n2017  Apr.\n2017  May\n2017  Jun.\n2017  ...
# 4           NaN         NaN         NaN        NaN         NaN  ...
# ..          ...         ...         ...        ...         ...  ...
# 419         NaN         NaN         NaN        NaN         NaN  ...
# 420         NaN         NaN         NaN        NaN         NaN  ...
# 421         NaN         NaN         NaN        NaN         NaN  ...
# 422         NaN         NaN         NaN        NaN         NaN  ...
# 423         NaN         NaN         NaN        NaN         NaN  ...
#
#                  Unnamed: 34              Unnamed: 35  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3    Oct.\n2017-\nNov.\n2017  Nov.\n2017-\nDec.\n2017
# 4                        NaN                      NaN
# ..                       ...                      ...
# 419                      NaN                      NaN
# 420                      NaN                      NaN
# 421                      NaN                      NaN
# 422                      NaN                      NaN
# 423                      NaN                      NaN
#
#                                            Unnamed: 36  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                            One Month
# 3    Seasonally adjusted effect on All Items\nNov. ...
# 4                                                  NaN
# ..                                                 ...
# 419                                                NaN
# 420                                                NaN
# 421                                                NaN
# 422                                                NaN
# 423                                                NaN
#
#                                 Unnamed: 37  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3    Standard error, median price change(2)
# 4                                       NaN
# ..                                      ...
# 419                                     NaN
# 420                                     NaN
# 421                                     NaN
# 422                                     NaN
# 423                                     NaN
#
#                                            Unnamed: 38     Unnamed: 39  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                                  NaN             NaN
# 3    Largest (L) or Smallest (S) seasonally adjuste...             NaN
# 4                                                 Date  Percent change
# ..                                                 ...             ...
# 419                                                NaN             NaN
# 420                                                NaN             NaN
# 421                                                NaN             NaN
# 422                                                NaN             NaN
# 423                                                NaN             NaN
#
#                                            Unnamed: 40  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                         Twelve Month
# 3    Unadjusted effect on All Items\nDec. 2016-\nDe...
# 4                                                  NaN
# ..                                                 ...
# 419                                                NaN
# 420                                                NaN
# 421                                                NaN
# 422                                                NaN
# 423                                                NaN
#
#                                 Unnamed: 41  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3    Standard error, median price change(2)
# 4                                       NaN
# ..                                      ...
# 419                                     NaN
# 420                                     NaN
# 421                                     NaN
# 422                                     NaN
# 423                                     NaN
#
#                                            Unnamed: 42     Unnamed: 43
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                                  NaN             NaN
# 3    Largest (L) or Smallest (S) unadjusted change ...             NaN
# 4                                                 Date  Percent change
# ..                                                 ...             ...
# 419                                                NaN             NaN
# 420                                                NaN             NaN
# 421                                                NaN             NaN
# 422                                                NaN             NaN
# 423                                                NaN             NaN
#
# [424 rows x 44 columns]

# %%
import requests
import json
#import prettytable
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"2011", "endyear":"2014"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
json_data
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 133,
#  'message': [],
#  'Results': {'series': [{'seriesID': 'CUUR0000SA0',
#     'data': [{'year': '2014',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '234.812',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.6', '3': '-1.4', '6': '-1.5', '12': '0.8'}}},
#      {'year': '2014',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '236.151',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.5', '3': '-0.7', '6': '-0.7', '12': '1.3'}}},
#      {'year': '2014',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '237.433',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.3', '3': '-0.3', '6': '0.2', '12': '1.7'}}},
#      {'year': '2014',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '238.031',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '-0.1', '6': '0.7', '12': '1.7'}}},
#      {'year': '2014',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '237.852',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.2', '3': '0.0', '6': '1.3', '12': '1.7'}}},
#      {'year': '2014',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '238.250',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '0.5', '6': '1.9', '12': '2.0'}}},
#      {'year': '2014',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '238.343',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '0.9', '6': '2.3', '12': '2.1'}}},
#      {'year': '2014',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '237.900',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '1.3', '6': '2.1', '12': '2.1'}}},
#      {'year': '2014',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '237.072',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '1.3', '6': '1.5', '12': '2.0'}}},
#      {'year': '2014',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '236.293',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.6', '3': '1.4', '6': '0.9', '12': '1.5'}}},
#      {'year': '2014',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '234.781',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '0.7', '6': '0.4', '12': '1.1'}}},
#      {'year': '2014',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '233.916',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '0.2', '6': '0.1', '12': '1.6'}}},
#      {'year': '2013',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '233.049',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '-0.5', '6': '-0.2', '12': '1.5'}}},
#      {'year': '2013',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '233.069',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.2', '3': '-0.3', '6': '0.1', '12': '1.2'}}},
#      {'year': '2013',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '233.546',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.3', '3': '0.0', '6': '0.4', '12': '1.0'}}},
#      {'year': '2013',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '234.149',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '0.3', '6': '0.6', '12': '1.2'}}},
#      {'year': '2013',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '233.877',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '0.4', '6': '0.7', '12': '1.5'}}},
#      {'year': '2013',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '233.596',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '0.5', '6': '1.4', '12': '2.0'}}},
#      {'year': '2013',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '233.504',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '0.3', '6': '1.7', '12': '1.8'}}},
#      {'year': '2013',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '232.945',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '0.3', '6': '1.2', '12': '1.4'}}},
#      {'year': '2013',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '232.531',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.1', '3': '1.0', '6': '0.5', '12': '1.1'}}},
#      {'year': '2013',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '232.773',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '1.4', '6': '0.6', '12': '1.5'}}},
#      {'year': '2013',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '232.166',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.8', '3': '0.8', '6': '0.8', '12': '2.0'}}},
#      {'year': '2013',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '230.280',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '-0.4', '6': '0.5', '12': '1.6'}}},
#      {'year': '2012',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '229.601',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.3', '3': '-0.8', '6': '0.1', '12': '1.7'}}},
#      {'year': '2012',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '230.221',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.5', '3': '-0.1', '6': '0.2', '12': '1.8'}}},
#      {'year': '2012',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '231.317',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.0', '3': '1.0', '6': '0.5', '12': '2.2'}}},
#      {'year': '2012',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '231.407',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '0.8', '6': '0.9', '12': '2.0'}}},
#      {'year': '2012',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '230.379',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.6', '3': '0.2', '6': '1.2', '12': '1.7'}}},
#      {'year': '2012',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '229.104',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.2', '3': '-0.4', '6': '1.1', '12': '1.4'}}},
#      {'year': '2012',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '229.478',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.1', '3': '0.0', '6': '1.7', '12': '1.7'}}},
#      {'year': '2012',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '229.815',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.1', '3': '0.9', '6': '1.6', '12': '1.7'}}},
#      {'year': '2012',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '230.085',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '1.5', '6': '1.6', '12': '2.3'}}},
#      {'year': '2012',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '229.392',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.8', '3': '1.6', '6': '1.1', '12': '2.7'}}},
#      {'year': '2012',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '227.663',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '0.6', '6': '0.5', '12': '2.9'}}},
#      {'year': '2012',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '226.665',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.4', '3': '0.1', '6': '0.3', '12': '2.9'}}},
#      {'year': '2011',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '225.672',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.2', '3': '-0.5', '6': '0.0', '12': '3.0'}}},
#      {'year': '2011',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '226.230',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.1', '3': '-0.1', '6': '0.1', '12': '3.4'}}},
#      {'year': '2011',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '226.421',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.2', '3': '0.2', '6': '0.7', '12': '3.5'}}},
#      {'year': '2011',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '226.889',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.2', '3': '0.5', '6': '1.5', '12': '3.9'}}},
#      {'year': '2011',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '226.545',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.3', '3': '0.3', '6': '2.4', '12': '3.8'}}},
#      {'year': '2011',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '225.922',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.1', '3': '0.5', '6': '2.6', '12': '3.6'}}},
#      {'year': '2011',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '225.722',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '-0.1', '3': '1.0', '6': '3.0', '12': '3.6'}}},
#      {'year': '2011',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '225.964',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.5', '3': '2.1', '6': '3.3', '12': '3.6'}}},
#      {'year': '2011',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '224.906',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.6', '3': '2.1', '6': '2.8', '12': '3.2'}}},
#      {'year': '2011',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '223.467',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '1.0', '3': '2.0', '6': '2.3', '12': '2.7'}}},
#      {'year': '2011',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '221.309',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.5', '3': '1.1', '6': '1.4', '12': '2.1'}}},
#      {'year': '2011',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '220.223',
#       'footnotes': [{}],
#       'calculations': {'net_changes': {},
#        'pct_changes': {'1': '0.5', '3': '0.7', '6': '1.0', '12': '1.6'}}}]},
#    {'seriesID': 'SUUR0000SA0',
#     'data': [{'year': '2014',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '134.207',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '135.107',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '135.891',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '136.211',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '136.127',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '136.392',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '136.433',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '136.216',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '135.771',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '135.375',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '134.542',
#       'footnotes': [{}]},
#      {'year': '2014',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '134.017',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '133.509',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '133.596',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '133.876',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '134.255',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '134.098',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '133.919',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '133.900',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '133.626',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '133.421',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '133.558',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '133.204',
#       'footnotes': [{}]},
#      {'year': '2013',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '132.137',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '131.770',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '132.208',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '132.892',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '132.988',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '132.430',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '131.731',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '131.956',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '132.154',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '132.284',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '131.905',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '130.953',
#       'footnotes': [{}]},
#      {'year': '2012',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '130.438',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '129.844',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '130.196',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '130.373',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '130.635',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '130.351',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '129.983',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '129.846',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '129.999',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '129.483',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '128.585',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '127.363',
#       'footnotes': [{}]},
#      {'year': '2011',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '126.778',
#       'footnotes': [{}]}]}]}}
